# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
root_1929_slices_per_sec_mean = np.load('root/root_slices_per_sec_mean_1929.npy')
root_3858_slices_per_sec_mean = np.load('root/root_slices_per_sec_mean_3858.npy')
root_7716_slices_per_sec_mean = np.load('root/root_slices_per_sec_mean_7716.npy')

root_1929_slices_per_sec_errs = np.load('root/root_slices_per_sec_errs_1929.npy')
root_3858_slices_per_sec_errs = np.load('root/root_slices_per_sec_errs_3858.npy')
root_7716_slices_per_sec_errs = np.load('root/root_slices_per_sec_errs_7716.npy')

# %%
hepnos_v1_1929_slices_per_sec_mean = np.load('hepnos/v1/slices_per_sec_mean_1929.npy')
hepnos_v1_3858_slices_per_sec_mean = np.load('hepnos/v1/slices_per_sec_mean_3858.npy')
hepnos_v1_7716_slices_per_sec_mean = np.load('hepnos/v1/slices_per_sec_mean_7716.npy')

hepnos_v1_1929_slices_per_sec_errs = np.load('hepnos/v1/slices_per_sec_errs_1929.npy')
hepnos_v1_3858_slices_per_sec_errs = np.load('hepnos/v1/slices_per_sec_errs_3858.npy')
hepnos_v1_7716_slices_per_sec_errs = np.load('hepnos/v1/slices_per_sec_errs_7716.npy')

# %%
hepnos_v2_1929_slices_per_sec_mean = np.load('hepnos/v2/slices_per_sec_mean_1929.npy')
hepnos_v2_3858_slices_per_sec_mean = np.load('hepnos/v2/slices_per_sec_mean_3858.npy')
hepnos_v2_7716_slices_per_sec_mean = np.load('hepnos/v2/slices_per_sec_mean_7716.npy')

hepnos_v2_1929_slices_per_sec_errs = np.load('hepnos/v2/slices_per_sec_errs_1929.npy')
hepnos_v2_3858_slices_per_sec_errs = np.load('hepnos/v2/slices_per_sec_errs_3858.npy')
hepnos_v2_7716_slices_per_sec_errs = np.load('hepnos/v2/slices_per_sec_errs_7716.npy')

# %%
nodes = np.array([8,16,32,64,128])

mpl.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 18
plt.rcParams['axes.linewidth'] = 0.5
mpl.rcParams['lines.markersize'] = 6

f,ax = plt.subplots(1,3)
f.set_size_inches(32,10)
f.subplots_adjust(wspace=0)

_elinewidth = 0.75
_capsize = 3

ax[0].set_title('1929 files')
ax[0].errorbar(np.arange(5), hepnos_v1_1929_slices_per_sec_mean, yerr=hepnos_v1_1929_slices_per_sec_errs, fmt='b-.d', ecolor='b', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-v1')
ax[0].plot(np.arange(5), (hepnos_v1_1929_slices_per_sec_mean[0])*(nodes/nodes[0]), 'b--.', alpha=0.35)
ax[0].errorbar(np.arange(5), hepnos_v2_1929_slices_per_sec_mean, yerr=hepnos_v2_1929_slices_per_sec_errs, fmt='g-o', ecolor='g', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-v1')
ax[0].plot(np.arange(5), (hepnos_v2_1929_slices_per_sec_mean[0])*(nodes/nodes[0]), 'g--.', alpha=0.35)
ax[0].errorbar(np.arange(5), root_1929_slices_per_sec_mean, yerr=root_1929_slices_per_sec_errs, fmt='m-x', ecolor='m', elinewidth=_elinewidth, capsize=_capsize, label='ROOT')
ax[0].plot(np.arange(5), (root_1929_slices_per_sec_mean[0])*(nodes/nodes[0]), 'm--.', alpha=0.35)

ax[1].set_title('3858 files')
ax[1].errorbar(np.arange(5), hepnos_v1_3858_slices_per_sec_mean, yerr=hepnos_v1_3858_slices_per_sec_errs, fmt='b-.d', ecolor='b', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-v1')
ax[1].plot(np.arange(5), (hepnos_v1_3858_slices_per_sec_mean[0])*(nodes/nodes[0]), 'b--.', alpha=0.35)
ax[1].errorbar(np.arange(5), hepnos_v2_3858_slices_per_sec_mean, yerr=hepnos_v2_3858_slices_per_sec_errs, fmt='g-o', ecolor='g', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-v1')
ax[1].plot(np.arange(5), (hepnos_v2_3858_slices_per_sec_mean[0])*(nodes/nodes[0]), 'g--.', alpha=0.35)
ax[1].errorbar(np.arange(5), root_3858_slices_per_sec_mean, yerr=root_3858_slices_per_sec_errs, fmt='m-x', ecolor='m', elinewidth=_elinewidth, capsize=_capsize, label='ROOT')
ax[1].plot(np.arange(5), (root_3858_slices_per_sec_mean[0])*(nodes/nodes[0]), 'm--.', alpha=0.35)

ax[2].set_title('7716 files')
ax[2].errorbar(np.arange(5), hepnos_v1_7716_slices_per_sec_mean, yerr=hepnos_v1_7716_slices_per_sec_errs, fmt='b-.d', ecolor='b', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-v1')
ax[2].plot(np.arange(5), (hepnos_v1_7716_slices_per_sec_mean[0])*(nodes/nodes[0]), 'b--.', alpha=0.35)
ax[2].errorbar(np.arange(5), hepnos_v2_7716_slices_per_sec_mean, yerr=hepnos_v2_7716_slices_per_sec_errs, fmt='g-o', ecolor='g', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-v1')
ax[2].plot(np.arange(5), (hepnos_v2_7716_slices_per_sec_mean[0])*(nodes/nodes[0]), 'g--.', alpha=0.35)
ax[2].errorbar(np.arange(5), root_7716_slices_per_sec_mean, yerr=root_7716_slices_per_sec_errs, fmt='m-x', ecolor='m', elinewidth=_elinewidth, capsize=_capsize, label='ROOT')
ax[2].plot(np.arange(5), (root_7716_slices_per_sec_mean[0])*(nodes/nodes[0]), 'm--.', alpha=0.35)

# Common legend for all plots!
lgd = ax[1].legend(bbox_to_anchor=(0.925, -0.125), ncol=3)

for _ax in ax:
    _ax.set_xticks(np.arange(5))
    _ax.set_xticklabels(nodes)
    _ax.set_xlabel('Nodes', labelpad=10)
    _ax.set_yscale('log', base=10)
    #_ax.set_ylim(10**4,10**7)
    _ax.xaxis.set_tick_params(which='major', size=10, width=2)
    _ax.xaxis.set_tick_params(which='minor', size=7, width=2)
    _ax.yaxis.set_tick_params(which='major', size=10, width=2)
    _ax.yaxis.set_tick_params(which='minor', size=7, width=2)
    if _ax==ax[0]:
        _ax.set_ylabel('throughpout slices processed/sec', labelpad=10)
    else:
        _ax.yaxis.set_ticklabels([])
        _ax.yaxis.set_ticks([])
        _ax.yaxis.set_ticks([], minor=True)

plt.savefig("slice_throughput.png", dpi=250, bbox_inches="tight")
