# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

pwd = os.getcwd()

# %%
times_combined = pd.DataFrame(
    {
        "files" : [],
        "server_nodes_fraction" : [],
        "server_rpc_xstreams_per_MPI_rank" : [],
        "total_num_nodes" : [],
        "MPI_rank_among_clients" : [],
        "expt_number" : [],
        "analysis_start_times" : [],
        "pep_start_times" : [],
        "pep_end_times" : [],
        "analysis_end_times" : [],
        "analysis_method" : [],
    }
)

df_root = pd.read_csv("root/root-hepnos.csv")

df_ssd_hepnos = pd.read_csv("ssd_hepnos/servers_one_eigth/16MPI_ranks_per_node/ssd-hepnos.csv")

df_hepnos = pd.read_csv("hepnos/servers_one_eigth/16MPI_ranks_per_node/map-hepnos.csv")

times_combined = pd.concat([times_combined, df_root, df_ssd_hepnos, df_hepnos], ignore_index=True)

os.chdir(pwd)
times_combined.to_csv("times-combined.csv")

# %%
times_combined
# Out:
#          files  server_nodes_fraction  server_rpc_xstreams_per_MPI_rank  \
# 0       1929.0                    NaN                               NaN
# 1       1929.0                    NaN                               NaN
# 2       1929.0                    NaN                               NaN
# 3       1929.0                    NaN                               NaN
# 4       1929.0                    NaN                               NaN
# ...        ...                    ...                               ...
# 179605  7716.0                  0.125                              16.0
# 179606  7716.0                  0.125                              16.0
# 179607  7716.0                  0.125                              16.0
# 179608  7716.0                  0.125                              16.0
# 179609  7716.0                  0.125                              16.0
#
#         total_num_nodes  MPI_rank_among_clients  expt_number  \
# 0                   8.0                     NaN          1.0
# 1                  16.0                     NaN          1.0
# 2                  16.0                     NaN          2.0
# 3                  16.0                     NaN          3.0
# 4                  16.0                     NaN          4.0
# ...                 ...                     ...          ...
# 179605            256.0                  2001.0          5.0
# 179606            256.0                  1509.0          5.0
# 179607            256.0                  1613.0          5.0
# 179608            256.0                  2275.0          5.0
# 179609            256.0                  3084.0          5.0
#
#         analysis_start_times  pep_start_times  pep_end_times  \
# 0                        NaN              NaN            NaN
# 1                        NaN              NaN            NaN
# 2                        NaN              NaN            NaN
# 3                        NaN              NaN            NaN
# 4                        NaN              NaN            NaN
# ...                      ...              ...            ...
# 179605              0.000488          3.28214        92.8181
# 179606              0.000465          3.32572        93.1997
# 179607              0.000460          3.30330        93.5123
# 179608              0.000485          3.29968        95.0132
# 179609              0.000478          3.30321        98.8032
#
#         analysis_end_times analysis_method  Unnamed: 0
# 0                  390.000            ROOT         0.0
# 1                  212.000            ROOT         1.0
# 2                  218.000            ROOT         2.0
# 3                  217.000            ROOT         3.0
# 4                  215.000            ROOT         4.0
# ...                    ...             ...         ...
# 179605             102.764      HEPnOS-map    104491.0
# 179606             102.828      HEPnOS-map    104492.0
# 179607             102.789      HEPnOS-map    104493.0
# 179608             102.765      HEPnOS-map    104494.0
# 179609             102.943      HEPnOS-map    104495.0
#
# [179610 rows x 12 columns]

# %%
times_combined[(times_combined["total_num_nodes"] == 128) &
               (times_combined["files"] == 3858) &
               (
                (times_combined["analysis_method"] == "HEPnOS-rocksdb") | 
                (times_combined["analysis_method"] == "HEPnOS-map") | 
                (times_combined["analysis_method"] == "ROOT") 
               ) &
               (
                   (times_combined["MPI_rank_among_clients"] == 0) |
                   (times_combined["MPI_rank_among_clients"].isna() )
               )
              ]
# Out:
#          files  server_nodes_fraction  server_rpc_xstreams_per_MPI_rank  \
# 42      3858.0                    NaN                               NaN
# 43      3858.0                    NaN                               NaN
# 44      3858.0                    NaN                               NaN
# 45      3858.0                    NaN                               NaN
# 46      3858.0                    NaN                               NaN
# 40026   3858.0                  0.125                              16.0
# 42668   3858.0                  0.125                              16.0
# 118298  3858.0                  0.125                              16.0
# 120634  3858.0                  0.125                              16.0
# 122948  3858.0                  0.125                              16.0
# 124840  3858.0                  0.125                              16.0
# 125788  3858.0                  0.125                              16.0
#
#         total_num_nodes  MPI_rank_among_clients  expt_number  \
# 42                128.0                     NaN          1.0
# 43                128.0                     NaN          2.0
# 44                128.0                     NaN          3.0
# 45                128.0                     NaN          4.0
# 46                128.0                     NaN          5.0
# 40026             128.0                     0.0          1.0
# 42668             128.0                     0.0          2.0
# 118298            128.0                     0.0          1.0
# 120634            128.0                     0.0          2.0
# 122948            128.0                     0.0          3.0
# 124840            128.0                     0.0          4.0
# 125788            128.0                     0.0          5.0
#
#         analysis_start_times  pep_start_times  pep_end_times  \
# 42                       NaN              NaN            NaN
# 43                       NaN              NaN            NaN
# 44                       NaN              NaN            NaN
# 45                       NaN              NaN            NaN
# 46                       NaN              NaN            NaN
# 40026               0.000444          2.05955        61.6516
# 42668               0.000480          1.93682        62.0648
# 118298              0.000469          2.04371        60.9757
# 120634              0.000487          1.97144        56.1954
# 122948              0.000465          1.95405        58.6820
# 124840              0.000457          1.97961        60.5076
# 125788              0.000487          2.10892        60.0448
#
#         analysis_end_times analysis_method  Unnamed: 0
# 42                 97.0000            ROOT        42.0
# 43                103.0000            ROOT        43.0
# 44                103.0000            ROOT        44.0
# 45                 97.0000            ROOT        45.0
# 46                 98.0000            ROOT        46.0
# 40026              65.1053  HEPnOS-rocksdb     39952.0
# 42668              65.8532  HEPnOS-rocksdb     42594.0
# 118298             64.4453      HEPnOS-map     43184.0
# 120634             60.8790      HEPnOS-map     45520.0
# 122948             62.1985      HEPnOS-map     47834.0
# 124840             64.8197      HEPnOS-map     49726.0
# 125788             64.0482      HEPnOS-map     50674.0
