# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
_es1929 = []
_es3858 = []
_es7716 = []

# %%
#################################
## RAW TIMING DATA ##
#################################

#5_4_597887
_es1929.append([95.31994, 46.695719999999994, 25.45943, 19.51409])
_es1929.append([95.35509, 46.73587, 25.9148, 23.118100000000005])
_es1929.append([95.82108,  47.356899999999996, 27.579300000000003])

#5_7_598234
_es1929.append([95.60272, 47.96058, 27.5886, 20.627119999999998])
_es1929.append([95.67852])

#5_9_598549
_es1929.append([95.13376, 46.84306, 24.86816, 20.047])
_es1929.append([95.19417])

#################################
## COMBINE RAW DATA ##
#################################

es1929 = [[],[],[],[],[]]

es1929[0].append(217.21175)

for i in _es1929:
    if len(i)>0:
        es1929[1].append(i[0])
    if len(i)>1:
        es1929[2].append(i[1])
    if len(i)>2:
        es1929[3].append(i[2])
    if len(i)>3:
        es1929[4].append(i[3])
        
#################################
## MEAN, MIN, MAX for plotting ##
#################################
means_1929 = []
errs_1929_min  = []
errs_1929_max  = []

for i in range(5):
    means_1929.append(np.mean(es1929[i]))
    if len(es1929[i])<=1:
        errs_1929_min.append(0)
        errs_1929_max.append(0)
    else:
        errs_1929_min.append(np.mean(es1929[i]) - np.min(es1929[i]))
        errs_1929_max.append(np.max(es1929[i]) - np.mean(es1929[i]))
        
means1929 = np.array(means_1929)
errs1929 = np.zeros((2,5))
errs1929[0,:] = errs_1929_min
errs1929[1,:] = errs_1929_max

# %%
#################################
## RAW TIMING DATA ##
#################################

#5_13_599358
_es3858.append([189.36612, 92.21340000000001, 48.2239, 32.80391])
_es3858.append([189.29076, 92.43021, 49.793749999999996, 41.2669])
_es3858.append([189.33847, 92.73060000000001, 50.775099999999995, 49.918800000000005])

#5_17_599899
_es3858.append([188.90005, 90.38383, 49.40795, 34.14041])
_es3858.append([189.06503, 90.58397, 49.92754, 40.056599999999996])
_es3858.append([188.89252, 91.57062, 51.035999999999994, 47.4925])
_es3858.append([230.29212, 91.78970000000001])

#################################
## COMBINE RAW DATA ##
#################################

es3858 = [[],[],[],[],[]]

es3858[0].append(442.30785)

for i in _es3858:
    if len(i)>0:
        es3858[1].append(i[0])
    if len(i)>1:
        es3858[2].append(i[1])
    if len(i)>2:
        es3858[3].append(i[2])
    if len(i)>3:
        es3858[4].append(i[3])
        
#################################
## MEAN, MIN, MAX for plotting ##
#################################
means_3858 = []
errs_3858_min  = []
errs_3858_max  = []

for i in range(5):
    means_3858.append(np.mean(es3858[i]))
    if len(es3858[i])<=1:
        errs_3858_min.append(0)
        errs_3858_max.append(0)
    else:
        errs_3858_min.append(np.mean(es3858[i]) - np.min(es3858[i]))
        errs_3858_max.append(np.max(es3858[i]) - np.mean(es3858[i]))
        
means3858 = np.array(means_3858)
errs3858 = np.zeros((2,5))
errs3858[0,:] = errs_3858_min
errs3858[1,:] = errs_3858_max

# %%
#################################
## RAW TIMING DATA ##
#################################

#5_14_599399
_es7716.append([378.29872, 178.1581, 92.052, 61.345299999999995])
_es7716.append([378.19428, 178.65824, 92.44396, 76.955])
_es7716.append([377.91018])
               
#5_17_599850
_es7716.append([378.0713, 178.03255, 92.36376, 58.4169])
_es7716.append([377.56291, 177.86264,  92.47616])

#5_17_599860
_es7716.append([377.62285, 178.75699, 94.7763, 61.4636])
_es7716.append([377.77189, 178.51127, 95.144, 74.8257])
_es7716.append([377.32393])

#################################
## COMBINE RAW DATA ##
#################################

es7716 = [[],[],[],[],[]]

es7716[0].append( 884.17626)

for i in _es7716:
    if len(i)>0:
        es7716[1].append(i[0])
    if len(i)>1:
        es7716[2].append(i[1])
    if len(i)>2:
        es7716[3].append(i[2])
    if len(i)>3:
        es7716[4].append(i[3])
        
#################################
## MEAN, MIN, MAX for plotting ##
#################################
means_7716 = []
errs_7716_min  = []
errs_7716_max  = []

for i in range(5):
    means_7716.append(np.mean(es7716[i]))
    if len(es7716[i])<=1:
        errs_7716_min.append(0)
        errs_7716_max.append(0)
    else:
        errs_7716_min.append(np.mean(es7716[i]) - np.min(es7716[i]))
        errs_7716_max.append(np.max(es7716[i]) - np.mean(es7716[i]))
        
means7716 = np.array(means_7716)
errs7716 = np.zeros((2,5))
errs7716[0,:] = errs_7716_min
errs7716[1,:] = errs_7716_max

# %%
np.save('means_1929.npy', means_1929)
np.save('means_3858.npy', means_3858)
np.save('means_7716.npy', means_7716)

np.save('errs1929.npy', errs1929)
np.save('errs3858.npy', errs3858)
np.save('errs7716.npy', errs7716)
