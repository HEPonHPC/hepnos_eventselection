# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nodes = np.array([8, 32, 64])
times = np.array([186.3, 45.6, 26.3])

# %%
ideal = times[0]*8/nodes
scaling = (ideal/times)*100

# %%
scaling
# Out:
# array([100.        , 102.13815789,  88.54562738])

# %%
f,ax = plt.subplots(1,1)

f.set_size_inches(10,8)

ax.plot(nodes,times, 'm-x')
ax.set_xlabel('Number of nodes', size=12)
ax.set_ylabel('PEP execution time in sec', color='m', size=12)

ax2 = ax.twinx()
ax2.plot(nodes,scaling, 'c--o')
ax2.set_ylabel('Strong Scaling efficiency %', color='c', size=12)
# Out:
# Text(0, 0.5, 'Strong Scaling efficiency %')
