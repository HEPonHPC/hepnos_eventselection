# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
_es1929 = []
_es3858 = []
_es7716 = []

# %%
#4_8_593191
_es1929.append([88.80783, 44.90772, 25.05399, 26.387159999999998])
_es1929.append([88.69608])

#4_10_593374
_es1929.append([88.62056, 45.2519, 25.38066])

#4_12_594053
_es1929.append([89.19849, 46.60324, 25.25175, 24.857509999999998])
_es1929.append([88.81643])

#4_13_594292
_es1929.append([89.27185, 44.80152, 25.15494])

# %%
es1929 = [[],[],[],[],[]]

es1929[0].append(186.25179)

for i in _es1929:
    if len(i)>0:
        es1929[1].append(i[0])
    if len(i)>1:
        es1929[2].append(i[1])
    if len(i)>2:
        es1929[3].append(i[2])
    if len(i)>3:
        es1929[4].append(i[3])

# %%
#4_19_595468
_es3858.append([176.65601, 89.03165, 46.868210000000005])

# %%
es3858 = [[],[],[],[],[]]

es3858[0].append(374.29184999999995)

for i in _es3858:
    if len(i)>0:
        es3858[1].append(i[0])
    if len(i)>1:
        es3858[2].append(i[1])
    if len(i)>2:
        es3858[3].append(i[2])
    if len(i)>3:
        es3858[4].append(i[3])

# %%
#4_20_595716
_es7716.append([352.14015, 173.36112, 91.97684])

# %%
96.8261 - 4.84926
# Out:
# 91.97684

# %%
es7716 = [[],[],[],[],[]]

es7716[0].append(752.8713)

for i in _es7716:
    if len(i)>0:
        es7716[1].append(i[0])
    if len(i)>1:
        es7716[2].append(i[1])
    if len(i)>2:
        es7716[3].append(i[2])
    if len(i)>3:
        es7716[4].append(i[3])

# %%
means_1929 = []
errs_1929_min  = []
errs_1929_max  = []

for i in range(5):
    means_1929.append(np.mean(es1929[i]))
    if len(es1929[i])<=1:
        errs_1929_min.append(0)
        errs_1929_max.append(0)
    else:
        errs_1929_min.append(np.mean(es1929[i]) - np.min(es1929[i]))
        errs_1929_max.append(np.max(es1929[i]) - np.mean(es1929[i]))
        
means1929 = np.array(means_1929)
errs1929 = np.zeros((2,5))
errs1929[0,:] = errs_1929_min
errs1929[1,:] = errs_1929_max

# %%
means_3858 = []
errs_3858_min  = []
errs_3858_max  = []

for i in range(5):
    means_3858.append(np.mean(es3858[i]))
    if len(es3858[i])<=1:
        errs_3858_min.append(0)
        errs_3858_max.append(0)
    else:
        errs_3858_min.append(np.mean(es3858[i]) - np.min(es3858[i]))
        errs_3858_max.append(np.max(es3858[i]) - np.mean(es3858[i]))
        
means3858 = np.array(means_3858)
errs3858 = np.zeros((2,5))
errs3858[0,:] = errs_3858_min
errs3858[1,:] = errs_3858_max
# Out:
# /home/sajid/miniconda3/envs/py3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/sajid/miniconda3/envs/py3/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
means_7716 = []
errs_7716_min  = []
errs_7716_max  = []

for i in range(5):
    means_7716.append(np.mean(es7716[i]))
    if len(es7716[i])<=1:
        errs_7716_min.append(0)
        errs_7716_max.append(0)
    else:
        errs_7716_min.append(np.mean(es7716[i]) - np.min(es7716[i]))
        errs_7716_max.append(np.max(es7716[i]) - np.mean(es7716[i]))
        
means7716 = np.array(means_7716)
errs7716 = np.zeros((2,5))
errs7716[0,:] = errs_7716_min
errs7716[1,:] = errs_7716_max

# %%
nodes = [8,16,32,64,128]




f,ax = plt.subplots(1,1)
f.set_size_inches(12,10)

ax.errorbar(np.arange(5), means1929, yerr=errs1929, fmt='m-', ecolor='b', elinewidth=5, label='1929 files')
ax.plot(np.arange(5), (means1929[0]*nodes[0])/nodes, 'm--.', alpha=0.5, label='1929 files ideal')
ax.errorbar(np.arange(5), means3858, yerr=errs3858, fmt='c-', ecolor='g', elinewidth=5, label='3858 files')
ax.plot(np.arange(5), (means3858[0]*nodes[0])/nodes, 'c--.', alpha=0.5, label='3858 files ideal')
ax.errorbar(np.arange(5), means7716, yerr=errs7716, fmt='k-', ecolor='y', elinewidth=5, label='7716 files')
ax.plot(np.arange(5), (means7716[0]*nodes[0])/nodes, 'k--.', alpha=0.5, label='7716 files ideal')
ax.set_xticks(np.arange(5))
ax.set_xticklabels(nodes)

ax.set_xlabel('Nodes', labelpad=10)
ax.set_ylabel('PEP time in sec', labelpad=10)

ax.set_yscale('log')
ax.set_ylim(10,1000)

ax.legend()

mpl.rcParams['font.family'] = 'Avenir'
plt.rcParams['font.size'] = 18
plt.rcParams['axes.linewidth'] = 2

ax.xaxis.set_tick_params(which='major', size=10, width=2)
ax.xaxis.set_tick_params(which='minor', size=7, width=2)
ax.yaxis.set_tick_params(which='major', size=10, width=2)
ax.yaxis.set_tick_params(which='minor', size=7, width=2)
# Out:
# findfont: Font family ['Avenir'] not found. Falling back to DejaVu Sans.
