# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
root_1929_slices_per_sec_mean = np.load('root/root_slices_per_sec_mean_1929.npy')
root_3858_slices_per_sec_mean = np.load('root/root_slices_per_sec_mean_3858.npy')
root_7716_slices_per_sec_mean = np.load('root/root_slices_per_sec_mean_7716.npy')

root_1929_slices_per_sec_errs = np.load('root/root_slices_per_sec_errs_1929.npy')
root_3858_slices_per_sec_errs = np.load('root/root_slices_per_sec_errs_3858.npy')
root_7716_slices_per_sec_errs = np.load('root/root_slices_per_sec_errs_7716.npy')

# %%
hepnos_s1_by_8_1929_slices_per_sec_mean = np.load('hepnos/servers_one_eigth/slices_per_sec_mean_1929.npy')
hepnos_s1_by_8_3858_slices_per_sec_mean = np.load('hepnos/servers_one_eigth/slices_per_sec_mean_3858.npy')
hepnos_s1_by_8_7716_slices_per_sec_mean = np.load('hepnos/servers_one_eigth/slices_per_sec_mean_7716.npy')

hepnos_s1_by_8_1929_slices_per_sec_errs = np.load('hepnos/servers_one_eigth/slices_per_sec_errs_1929.npy')
hepnos_s1_by_8_3858_slices_per_sec_errs = np.load('hepnos/servers_one_eigth/slices_per_sec_errs_3858.npy')
hepnos_s1_by_8_7716_slices_per_sec_errs = np.load('hepnos/servers_one_eigth/slices_per_sec_errs_7716.npy')

# %%
#ssd-hepnos-servers:1/8-1server/1node-...
ssd_h_s1_by_8_1s1n_1929_slices_per_sec_mean = np.load('ssd_hepnos/servers_one_eigth/one_server_per_node/slices_per_sec_mean_1929.npy')
ssd_h_s1_by_8_1s1n_3858_slices_per_sec_mean = np.load('ssd_hepnos/servers_one_eigth/one_server_per_node/slices_per_sec_mean_3858.npy')
ssd_h_s1_by_8_1s1n_7716_slices_per_sec_mean = np.load('ssd_hepnos/servers_one_eigth/one_server_per_node/slices_per_sec_mean_7716.npy')

ssd_h_s1_by_8_1s1n_1929_slices_per_sec_errs = np.load('ssd_hepnos/servers_one_eigth/one_server_per_node/slices_per_sec_errs_1929.npy')
ssd_h_s1_by_8_1s1n_3858_slices_per_sec_errs = np.load('ssd_hepnos/servers_one_eigth/one_server_per_node/slices_per_sec_errs_3858.npy')
ssd_h_s1_by_8_1s1n_7716_slices_per_sec_errs = np.load('ssd_hepnos/servers_one_eigth/one_server_per_node/slices_per_sec_errs_7716.npy')

# %%
#ssd-hepnos-servers:1/8-multiple_servers/1node-...
ssd_h_s1_by_8_ms1n_1929_slices_per_sec_mean = np.load('ssd_hepnos/servers_one_eigth/multi_servers_per_node/slices_per_sec_mean_1929.npy')
ssd_h_s1_by_8_ms1n_3858_slices_per_sec_mean = np.load('ssd_hepnos/servers_one_eigth/multi_servers_per_node/slices_per_sec_mean_3858.npy')
ssd_h_s1_by_8_ms1n_7716_slices_per_sec_mean = np.load('ssd_hepnos/servers_one_eigth/multi_servers_per_node/slices_per_sec_mean_7716.npy')

ssd_h_s1_by_8_ms1n_1929_slices_per_sec_errs = np.load('ssd_hepnos/servers_one_eigth/multi_servers_per_node/slices_per_sec_errs_1929.npy')
ssd_h_s1_by_8_ms1n_3858_slices_per_sec_errs = np.load('ssd_hepnos/servers_one_eigth/multi_servers_per_node/slices_per_sec_errs_3858.npy')
ssd_h_s1_by_8_ms1n_7716_slices_per_sec_errs = np.load('ssd_hepnos/servers_one_eigth/multi_servers_per_node/slices_per_sec_errs_7716.npy')

# %%
nodes = np.array([8,16,32,64,128,256])

mpl.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 18
plt.rcParams['axes.linewidth'] = 0.5
mpl.rcParams['lines.markersize'] = 6

f,ax = plt.subplots(1,3)
f.set_size_inches(32,10)
f.subplots_adjust(wspace=0)

_elinewidth = 0.75
_capsize = 3

ax[0].set_title('1929 files')
ax[0].errorbar(np.arange(5), root_1929_slices_per_sec_mean[:-1], yerr=root_1929_slices_per_sec_errs[:, :-1], fmt='y-o', ecolor='y', elinewidth=_elinewidth, capsize=_capsize, label='ROOT')
ax[0].errorbar(np.arange(6)[1:], hepnos_s1_by_8_1929_slices_per_sec_mean[1:], yerr=hepnos_s1_by_8_1929_slices_per_sec_errs[:,1:], fmt='g-^', ecolor='g', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-map-1/8')
ax[0].errorbar(np.arange(6)[1:], ssd_h_s1_by_8_1s1n_1929_slices_per_sec_mean[1:], yerr=ssd_h_s1_by_8_1s1n_1929_slices_per_sec_errs[:,1:], fmt='c-x', ecolor='c', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-rocksdb-1/8-1s1n')
ax[0].errorbar(np.arange(6)[1:], ssd_h_s1_by_8_ms1n_1929_slices_per_sec_mean[1:], yerr=ssd_h_s1_by_8_ms1n_1929_slices_per_sec_errs[:,1:], fmt='m--*', ecolor='m', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-rocksdb-1/8-1s1n')

ax[1].set_title('3858 files')
ax[1].errorbar(np.arange(6), root_3858_slices_per_sec_mean, yerr=root_3858_slices_per_sec_errs, fmt='y-o', ecolor='y', elinewidth=_elinewidth, capsize=_capsize, label='ROOT')
ax[1].errorbar(np.arange(6)[1:], hepnos_s1_by_8_3858_slices_per_sec_mean[1:], yerr=hepnos_s1_by_8_3858_slices_per_sec_errs[:,1:], fmt='g-^', ecolor='g', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-map-1/8')
ax[1].errorbar(np.arange(6)[1:], ssd_h_s1_by_8_1s1n_3858_slices_per_sec_mean[1:], yerr=ssd_h_s1_by_8_1s1n_3858_slices_per_sec_errs[:,1:], fmt='c-x', ecolor='c', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-rocksdb-1/8-1s1n')
ax[1].errorbar(np.arange(6)[1:], ssd_h_s1_by_8_ms1n_3858_slices_per_sec_mean[1:], yerr=ssd_h_s1_by_8_ms1n_3858_slices_per_sec_errs[:,1:], fmt='m--*', ecolor='m', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-rocksdb-1/8-1s1n')

ax[2].set_title('7716 files')
ax[2].errorbar(np.arange(6), root_7716_slices_per_sec_mean, yerr=root_7716_slices_per_sec_errs, fmt='y-o', ecolor='y', elinewidth=_elinewidth, capsize=_capsize, label='ROOT')
ax[2].errorbar(np.arange(6)[1:], hepnos_s1_by_8_7716_slices_per_sec_mean[1:], yerr=hepnos_s1_by_8_7716_slices_per_sec_errs[:,1:], fmt='g-^', ecolor='g', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-map-1/8')
ax[2].errorbar(np.arange(6)[1:], ssd_h_s1_by_8_1s1n_7716_slices_per_sec_mean[1:], yerr=ssd_h_s1_by_8_1s1n_7716_slices_per_sec_errs[:,1:], fmt='c-x', ecolor='c', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-rocksdb-1/8-1s1n')
ax[2].errorbar(np.arange(6)[1:], ssd_h_s1_by_8_ms1n_7716_slices_per_sec_mean[1:], yerr=ssd_h_s1_by_8_ms1n_7716_slices_per_sec_errs[:,1:], fmt='m--*', ecolor='m', elinewidth=_elinewidth, capsize=_capsize, label='HEPnOS-rocksdb-1/8-1s1n')

# Common legend for all plots!
lgd = ax[1].legend(bbox_to_anchor=(0.75, -0.125), ncol=2)

for _ax in ax:
    _ax.set_xticks(np.arange(6))
    _ax.set_xticklabels(nodes)
    _ax.set_xlabel('Nodes', labelpad=10)
    _ax.set_yscale('log', base=10)
    #_ax.set_ylim(10**4,10**7)
    _ax.xaxis.set_tick_params(which='major', size=10, width=2)
    _ax.xaxis.set_tick_params(which='minor', size=7, width=2)
    _ax.yaxis.set_tick_params(which='major', size=10, width=2)
    _ax.yaxis.set_tick_params(which='minor', size=7, width=2)
    if _ax==ax[0]:
        _ax.set_ylabel('Throughpout: slices processed/sec', labelpad=10, size=22)
    else:
        _ax.yaxis.set_ticklabels([])
        _ax.yaxis.set_ticks([])
        _ax.yaxis.set_ticks([], minor=True)
        
plt.savefig("one_eighth_servers_slice_throughput.png", dpi=250, bbox_inches="tight")
