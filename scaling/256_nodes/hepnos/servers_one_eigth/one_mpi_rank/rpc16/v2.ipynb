# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
_es1929 = []
_es3858 = []
_es7716 = []

# %%
#################################
## RAW TIMING DATA ##
#################################

#621235
_es1929.append([106.00765, 54.10799, 29.31194, 20.103319999999997, 25.92324])
_es1929.append([106.72761, 53.99205, 28.47996, 20.611269999999998, 28.07928])
_es1929.append([106.26827, 53.86795, 29.32394, 19.62318, 30.034290000000002])
_es1929.append([105.64755, 53.971979999999995, 29.53596, 19.03933, 31.54234])
_es1929.append([106.28389, 54.00394])

#################################
## COMBINE RAW DATA ##
#################################
          #8,16,32,64,128,256
es1929 = [[],[],[],[],[],[]]

es1929[0].append(0)

for i in _es1929:
    if len(i)>0:
        es1929[1].append(i[0])
    if len(i)>1:
        es1929[2].append(i[1])
    if len(i)>2:
        es1929[3].append(i[2])
    if len(i)>3:
        es1929[4].append(i[3])
    if len(i)>4:
        es1929[5].append(i[4])
        
#################################
## MEAN, MIN, MAX for plotting ##
#################################
means_1929 = []
errs_1929_min  = []
errs_1929_max  = []

for i in range(6):
    means_1929.append(np.mean(es1929[i]))
    if len(es1929[i])<=1:
        errs_1929_min.append(0)
        errs_1929_max.append(0)
    else:
        errs_1929_min.append(np.mean(es1929[i]) - np.min(es1929[i]))
        errs_1929_max.append(np.max(es1929[i]) - np.mean(es1929[i]))
        
means1929 = np.array(means_1929)
errs1929 = np.zeros((2,6))
errs1929[0,:] = errs_1929_min
errs1929[1,:] = errs_1929_max

# %%
#################################
## RAW TIMING DATA ##
#################################

#621291
_es3858.append([211.45941000000002, 106.90838000000001, 56.46799])

#621371
_es3858.append([212.10765, 106.78842, 56.25427, 33.33501, 32.10329])
_es3858.append([212.49557, 107.13194, 56.34391, 33.96727, 33.21131])
_es3858.append([212.05938999999998, 106.75167, 56.55598, 35.55129, 32.85105])
_es3858.append([211.35580000000002, 107.53213, 55.93599, 32.355199999999996, 32.40729])
_es3858.append([213.1635, 107.44763, 55.7545, 33.16736, 32.91125])

#################################
## COMBINE RAW DATA ##
#################################

es3858 = [[],[],[],[],[],[]]

es3858[0].append(0)

for i in _es3858:
    if len(i)>0:
        es3858[1].append(i[0])
    if len(i)>1:
        es3858[2].append(i[1])
    if len(i)>2:
        es3858[3].append(i[2])
    if len(i)>3:
        es3858[4].append(i[3])
    if len(i)>4:
        es3858[5].append(i[4])
        
#################################
## MEAN, MIN, MAX for plotting ##
#################################
means_3858 = []
errs_3858_min  = []
errs_3858_max  = []

for i in range(6):
    means_3858.append(np.mean(es3858[i]))
    if len(es3858[i])<=1:
        errs_3858_min.append(0)
        errs_3858_max.append(0)
    else:
        errs_3858_min.append(np.mean(es3858[i]) - np.min(es3858[i]))
        errs_3858_max.append(np.max(es3858[i]) - np.mean(es3858[i]))
        
means3858 = np.array(means_3858)
errs3858 = np.zeros((2,6))
errs3858[0,:] = errs_3858_min
errs3858[1,:] = errs_3858_max

# %%
#################################
## RAW TIMING DATA ##
#################################

#622091
_es7716.append([423.67221, 214.09627999999998, 111.21136, 63.623270000000005, 50.68736])
_es7716.append([422.46410000000003, 215.40439])

#622315
_es7716.append([424.43188000000004, 214.03570000000002, 109.99548, 61.975300000000004, 49.00333])
_es7716.append([427.42359, 213.88773999999998, 110.77920999999999, 62.53134, 48.241130000000005])
_es7716.append([424.51138000000003, 214.28533, 110.17075000000001, 62.45528])

#################################
## COMBINE RAW DATA ##
#################################

es7716 = [[],[],[],[],[],[]]

es7716[0].append(0)

for i in _es7716:
    if len(i)>0:
        es7716[1].append(i[0])
    if len(i)>1:
        es7716[2].append(i[1])
    if len(i)>2:
        es7716[3].append(i[2])
    if len(i)>3:
        es7716[4].append(i[3])
    if len(i)>4:
        es7716[5].append(i[4])
        
#################################
## MEAN, MIN, MAX for plotting ##
#################################
means_7716 = []
errs_7716_min  = []
errs_7716_max  = []

for i in range(6):
    means_7716.append(np.mean(es7716[i]))
    if len(es7716[i])<=1:
        errs_7716_min.append(0)
        errs_7716_max.append(0)
    else:
        errs_7716_min.append(np.mean(es7716[i]) - np.min(es7716[i]))
        errs_7716_max.append(np.max(es7716[i]) - np.mean(es7716[i]))
        
means7716 = np.array(means_7716)
errs7716 = np.zeros((2,6))
errs7716[0,:] = errs_7716_min
errs7716[1,:] = errs_7716_max

# %%
total_slices = 17878347

# %%
slices_per_sec_mean_1929 = total_slices/means1929
slices_per_sec_mean_3858 = (total_slices * 2)/means3858
slices_per_sec_mean_7716 = (total_slices * 4)/means7716
# Out:
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/3900409800.py:1: RuntimeWarning: divide by zero encountered in divide
#   slices_per_sec_mean_1929 = total_slices/means1929
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/3900409800.py:2: RuntimeWarning: divide by zero encountered in divide
#   slices_per_sec_mean_3858 = (total_slices * 2)/means3858
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/3900409800.py:3: RuntimeWarning: divide by zero encountered in divide
#   slices_per_sec_mean_7716 = (total_slices * 4)/means7716

# %%
slices_per_sec_errs_1929 = np.array([
                            + total_slices/(means1929 - errs1929[0,:]) - total_slices/means1929,
                            - total_slices/(means1929 + errs1929[1,:]) + total_slices/means1929,
                            ])

slices_per_sec_errs_3858 = np.array([
                            + (total_slices * 2)/(means3858 - errs3858[0,:]) - (total_slices * 2)/means3858,
                            - (total_slices * 2)/(means3858 + errs3858[1,:]) + (total_slices * 2)/means3858,
                            ])

slices_per_sec_errs_7716 = np.array([
                            + (total_slices * 4)/(means_7716 - errs7716[0,:]) - (total_slices * 4)/means7716,
                            - (total_slices * 4)/(means_7716 + errs7716[1,:]) + (total_slices * 4)/means7716,
                            ])
# Out:
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/2681382997.py:2: RuntimeWarning: divide by zero encountered in divide
#   + total_slices/(means1929 - errs1929[0,:]) - total_slices/means1929,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/2681382997.py:2: RuntimeWarning: invalid value encountered in subtract
#   + total_slices/(means1929 - errs1929[0,:]) - total_slices/means1929,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/2681382997.py:3: RuntimeWarning: divide by zero encountered in divide
#   - total_slices/(means1929 + errs1929[1,:]) + total_slices/means1929,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/2681382997.py:3: RuntimeWarning: invalid value encountered in add
#   - total_slices/(means1929 + errs1929[1,:]) + total_slices/means1929,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/2681382997.py:7: RuntimeWarning: divide by zero encountered in divide
#   + (total_slices * 2)/(means3858 - errs3858[0,:]) - (total_slices * 2)/means3858,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/2681382997.py:7: RuntimeWarning: invalid value encountered in subtract
#   + (total_slices * 2)/(means3858 - errs3858[0,:]) - (total_slices * 2)/means3858,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/2681382997.py:8: RuntimeWarning: divide by zero encountered in divide
#   - (total_slices * 2)/(means3858 + errs3858[1,:]) + (total_slices * 2)/means3858,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/2681382997.py:8: RuntimeWarning: invalid value encountered in add
#   - (total_slices * 2)/(means3858 + errs3858[1,:]) + (total_slices * 2)/means3858,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/2681382997.py:12: RuntimeWarning: divide by zero encountered in divide
#   + (total_slices * 4)/(means_7716 - errs7716[0,:]) - (total_slices * 4)/means7716,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/2681382997.py:12: RuntimeWarning: invalid value encountered in subtract
#   + (total_slices * 4)/(means_7716 - errs7716[0,:]) - (total_slices * 4)/means7716,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/2681382997.py:13: RuntimeWarning: divide by zero encountered in divide
#   - (total_slices * 4)/(means_7716 + errs7716[1,:]) + (total_slices * 4)/means7716,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_14659/2681382997.py:13: RuntimeWarning: invalid value encountered in add
#   - (total_slices * 4)/(means_7716 + errs7716[1,:]) + (total_slices * 4)/means7716,

# %%
np.save('slices_per_sec_mean_1929.npy', slices_per_sec_mean_1929)
np.save('slices_per_sec_mean_3858.npy', slices_per_sec_mean_3858)
np.save('slices_per_sec_mean_7716.npy', slices_per_sec_mean_7716)

np.save('slices_per_sec_errs_1929.npy', slices_per_sec_errs_1929)
np.save('slices_per_sec_errs_3858.npy', slices_per_sec_errs_3858)
np.save('slices_per_sec_errs_7716.npy', slices_per_sec_errs_7716)

# %%
np.save('means_1929.npy', means_1929)
np.save('means_3858.npy', means_3858)
np.save('means_7716.npy', means_7716)

np.save('errs1929.npy', errs1929)
np.save('errs3858.npy', errs3858)
np.save('errs7716.npy', errs7716)
