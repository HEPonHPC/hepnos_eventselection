# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
_es1929 = []
_es3858 = []
_es7716 = []

# %%
#################################
## RAW TIMING DATA ##
#################################


#621087
#_es1929.append([121.0036, 59.13595000000001,  40.5639, 43.455400000000004,  110.13929999999999])
_es1929.append([103.70746000000001, 55.50397, 40.9719, 34.71127, 56.923309999999994])
_es1929.append([103.02767, 56.203990000000005, 84.67194, 36.55921, 59.19911999999999])

#################################
## COMBINE RAW DATA ##
#################################
          #8,16,32,64,128,256
es1929 = [[],[],[],[],[],[]]
es1929[0].append(0)

for i in _es1929:
    if len(i)>0:
        es1929[1].append(i[0])
    if len(i)>1:
        es1929[2].append(i[1])
    if len(i)>2:
        es1929[3].append(i[2])
    if len(i)>3:
        es1929[4].append(i[3])
    if len(i)>4:
        es1929[5].append(i[4])
        
#################################
## MEAN, MIN, MAX for plotting ##
#################################
means_1929 = []
errs_1929_min  = []
errs_1929_max  = []

for i in range(6):
    means_1929.append(np.mean(es1929[i]))
    if len(es1929[i])<=1:
        errs_1929_min.append(0)
        errs_1929_max.append(0)
    else:
        errs_1929_min.append(np.mean(es1929[i]) - np.min(es1929[i]))
        errs_1929_max.append(np.max(es1929[i]) - np.mean(es1929[i]))
        
means1929 = np.array(means_1929)
errs1929 = np.zeros((2,6))
errs1929[0,:] = errs_1929_min
errs1929[1,:] = errs_1929_max

# %%
#################################
## RAW TIMING DATA ##
#################################

#621231
_es3858.append([204.90426, 108.16442, 152.55971, 56.779309999999995, 98.43109])
_es3858.append([205.51602, 160.29166, 151.30015, 56.96734, 77.2713])

#################################
## COMBINE RAW DATA ##
#################################

es3858 = [[],[],[],[],[],[]]

es3858[0].append(0)

for i in _es3858:
    if len(i)>0:
        es3858[1].append(i[0])
    if len(i)>1:
        es3858[2].append(i[1])
    if len(i)>2:
        es3858[3].append(i[2])
    if len(i)>3:
        es3858[4].append(i[3])
    if len(i)>4:
        es3858[5].append(i[4])
        
#################################
## MEAN, MIN, MAX for plotting ##
#################################
means_3858 = []
errs_3858_min  = []
errs_3858_max  = []

for i in range(6):
    means_3858.append(np.mean(es3858[i]))
    if len(es3858[i])<=1:
        errs_3858_min.append(0)
        errs_3858_max.append(0)
    else:
        errs_3858_min.append(np.mean(es3858[i]) - np.min(es3858[i]))
        errs_3858_max.append(np.max(es3858[i]) - np.mean(es3858[i]))
        
means3858 = np.array(means_3858)
errs3858 = np.zeros((2,6))
errs3858[0,:] = errs_3858_min
errs3858[1,:] = errs_3858_max

# %%
#################################
## RAW TIMING DATA ##
#################################

#621290
_es7716.append([410.02425, 208.58751999999998, 123.34398999999999, 98.68693])

#621370
_es7716.append([307.02035, 159.21225, 100.87631, 79.74323, 81.7353])
_es7716.append([309.32339, 239.99193000000002, 95.99194999999999, 103.82303, 81.98719])
_es7716.append([307.16003, 205.84409, 108.72012000000001, 148.06709, 119.94689])

#################################
## COMBINE RAW DATA ##
#################################

es7716 = [[],[],[],[],[],[]]

es7716[0].append(0)

for i in _es7716:
    if len(i)>0:
        es7716[1].append(i[0])
    if len(i)>1:
        es7716[2].append(i[1])
    if len(i)>2:
        es7716[3].append(i[2])
    if len(i)>3:
        es7716[4].append(i[3])
    if len(i)>4:
        es7716[5].append(i[4])
        
#################################
## MEAN, MIN, MAX for plotting ##
#################################
means_7716 = []
errs_7716_min  = []
errs_7716_max  = []

for i in range(6):
    means_7716.append(np.mean(es7716[i]))
    if len(es7716[i])<=1:
        errs_7716_min.append(0)
        errs_7716_max.append(0)
    else:
        errs_7716_min.append(np.mean(es7716[i]) - np.min(es7716[i]))
        errs_7716_max.append(np.max(es7716[i]) - np.mean(es7716[i]))
        
means7716 = np.array(means_7716)
errs7716 = np.zeros((2,6))
errs7716[0,:] = errs_7716_min
errs7716[1,:] = errs_7716_max

# %%
total_slices = 17878347

# %%
slices_per_sec_mean_1929 = total_slices/means1929
slices_per_sec_mean_3858 = (total_slices * 2)/means3858
slices_per_sec_mean_7716 = (total_slices * 4)/means7716
# Out:
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/3900409800.py:1: RuntimeWarning: divide by zero encountered in divide
#   slices_per_sec_mean_1929 = total_slices/means1929
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/3900409800.py:2: RuntimeWarning: divide by zero encountered in divide
#   slices_per_sec_mean_3858 = (total_slices * 2)/means3858
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/3900409800.py:3: RuntimeWarning: divide by zero encountered in divide
#   slices_per_sec_mean_7716 = (total_slices * 4)/means7716

# %%
slices_per_sec_errs_1929 = np.array([
                            + total_slices/(means1929 - errs1929[0,:]) - total_slices/means1929,
                            - total_slices/(means1929 + errs1929[1,:]) + total_slices/means1929,
                            ])

slices_per_sec_errs_3858 = np.array([
                            + (total_slices * 2)/(means3858 - errs3858[0,:]) - (total_slices * 2)/means3858,
                            - (total_slices * 2)/(means3858 + errs3858[1,:]) + (total_slices * 2)/means3858,
                            ])

slices_per_sec_errs_7716 = np.array([
                            + (total_slices * 4)/(means_7716 - errs7716[0,:]) - (total_slices * 4)/means7716,
                            - (total_slices * 4)/(means_7716 + errs7716[1,:]) + (total_slices * 4)/means7716,
                            ])
# Out:
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/2681382997.py:2: RuntimeWarning: divide by zero encountered in divide
#   + total_slices/(means1929 - errs1929[0,:]) - total_slices/means1929,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/2681382997.py:2: RuntimeWarning: invalid value encountered in subtract
#   + total_slices/(means1929 - errs1929[0,:]) - total_slices/means1929,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/2681382997.py:3: RuntimeWarning: divide by zero encountered in divide
#   - total_slices/(means1929 + errs1929[1,:]) + total_slices/means1929,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/2681382997.py:3: RuntimeWarning: invalid value encountered in add
#   - total_slices/(means1929 + errs1929[1,:]) + total_slices/means1929,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/2681382997.py:7: RuntimeWarning: divide by zero encountered in divide
#   + (total_slices * 2)/(means3858 - errs3858[0,:]) - (total_slices * 2)/means3858,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/2681382997.py:7: RuntimeWarning: invalid value encountered in subtract
#   + (total_slices * 2)/(means3858 - errs3858[0,:]) - (total_slices * 2)/means3858,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/2681382997.py:8: RuntimeWarning: divide by zero encountered in divide
#   - (total_slices * 2)/(means3858 + errs3858[1,:]) + (total_slices * 2)/means3858,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/2681382997.py:8: RuntimeWarning: invalid value encountered in add
#   - (total_slices * 2)/(means3858 + errs3858[1,:]) + (total_slices * 2)/means3858,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/2681382997.py:12: RuntimeWarning: divide by zero encountered in divide
#   + (total_slices * 4)/(means_7716 - errs7716[0,:]) - (total_slices * 4)/means7716,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/2681382997.py:12: RuntimeWarning: invalid value encountered in subtract
#   + (total_slices * 4)/(means_7716 - errs7716[0,:]) - (total_slices * 4)/means7716,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/2681382997.py:13: RuntimeWarning: divide by zero encountered in divide
#   - (total_slices * 4)/(means_7716 + errs7716[1,:]) + (total_slices * 4)/means7716,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_6991/2681382997.py:13: RuntimeWarning: invalid value encountered in add
#   - (total_slices * 4)/(means_7716 + errs7716[1,:]) + (total_slices * 4)/means7716,

# %%
np.save('slices_per_sec_mean_1929.npy', slices_per_sec_mean_1929)
np.save('slices_per_sec_mean_3858.npy', slices_per_sec_mean_3858)
np.save('slices_per_sec_mean_7716.npy', slices_per_sec_mean_7716)

np.save('slices_per_sec_errs_1929.npy', slices_per_sec_errs_1929)
np.save('slices_per_sec_errs_3858.npy', slices_per_sec_errs_3858)
np.save('slices_per_sec_errs_7716.npy', slices_per_sec_errs_7716)

# %%
np.save('means_1929.npy', means_1929)
np.save('means_3858.npy', means_3858)
np.save('means_7716.npy', means_7716)

np.save('errs1929.npy', errs1929)
np.save('errs3858.npy', errs3858)
np.save('errs7716.npy', errs7716)
