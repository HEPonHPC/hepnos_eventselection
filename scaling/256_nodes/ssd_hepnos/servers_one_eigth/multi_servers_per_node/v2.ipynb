# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
_es1929 = []
_es3858 = []
_es7716 = []

# %%
#################################
## RAW TIMING DATA ##
#################################

#624015
_es1929.append([105.65596, 57.731970000000004, 40.516, 36.139970000000005, 59.159949999999995])
_es1929.append([105.63623000000001, 56.49598, 40.483920000000005, 34.67198, 59.45196])
_es1929.append([104.62042, 57.81201, 42.8319, 35.19592, 59.799949999999995])
_es1929.append([105.58814000000001, 56.86407, 43.18094, 36.14308, 60.41597])
_es1929.append([105.94761000000001, 58.51993, 40.3559, 33.42396, 58.82791])

#################################
## COMBINE RAW DATA ##
#################################
          #8,16,32,64,128,256
es1929 = [[],[],[],[],[],[]]
es1929[0].append(204.60387)

for i in _es1929:
    if len(i)>0:
        es1929[1].append(i[0])
    if len(i)>1:
        es1929[2].append(i[1])
    if len(i)>2:
        es1929[3].append(i[2])
    if len(i)>3:
        es1929[4].append(i[3])
    if len(i)>4:
        es1929[5].append(i[4])
        
#################################
## MEAN, MIN, MAX for plotting ##
#################################
means_1929 = []
errs_1929_min  = []
errs_1929_max  = []

for i in range(6):
    means_1929.append(np.mean(es1929[i]))
    if len(es1929[i])<=1:
        errs_1929_min.append(0)
        errs_1929_max.append(0)
    else:
        errs_1929_min.append(np.mean(es1929[i]) - np.min(es1929[i]))
        errs_1929_max.append(np.max(es1929[i]) - np.mean(es1929[i]))
        
means1929 = np.array(means_1929)
errs1929 = np.zeros((2,6))
errs1929[0,:] = errs_1929_min
errs1929[1,:] = errs_1929_max

# %%
#################################
## RAW TIMING DATA ##
#################################

#624062
_es3858.append([207.04755, 109.2317, 74.21198999999999, 59.59205, 67.65201])
_es3858.append([207.96796, 109.46019, 77.02789, 60.12798, 67.93669])
_es3858.append([207.89204, 110.47196, 73.95998])

#################################
## COMBINE RAW DATA ##
#################################

es3858 = [[],[],[],[],[],[]]

es3858[0].append(410.44729)

for i in _es3858:
    if len(i)>0:
        es3858[1].append(i[0])
    if len(i)>1:
        es3858[2].append(i[1])
    if len(i)>2:
        es3858[3].append(i[2])
    if len(i)>3:
        es3858[4].append(i[3])
    if len(i)>4:
        es3858[5].append(i[4])
        
#################################
## MEAN, MIN, MAX for plotting ##
#################################
means_3858 = []
errs_3858_min  = []
errs_3858_max  = []

for i in range(6):
    means_3858.append(np.mean(es3858[i]))
    if len(es3858[i])<=1:
        errs_3858_min.append(0)
        errs_3858_max.append(0)
    else:
        errs_3858_min.append(np.mean(es3858[i]) - np.min(es3858[i]))
        errs_3858_max.append(np.max(es3858[i]) - np.mean(es3858[i]))
        
means3858 = np.array(means_3858)
errs3858 = np.zeros((2,6))
errs3858[0,:] = errs_3858_min
errs3858[1,:] = errs_3858_max

# %%
#################################
## RAW TIMING DATA ##
#################################

#_es7716.append([307.02035, 159.21225, 100.87631, 79.74323, 81.7353])
#9_29_624694
_es7716.append([414.51611, 213.44821, 138.93949999999998, 107.45572, 95.72801])
_es7716.append([415.10358])

#9_29_624848
_es7716.append([416.00965, 213.64844000000002, 136.60819, 104.29581, 98.55199999999999])
_es7716.append([414.4521])

#9_30_624892
_es7716.append([414.1556, 214.49895, 157.01955999999998, 102.54357999999999])

#9_30_624964
_es7716.append([413.40819000000005, 214.11201, 136.53582, 102.58785, 94.40391])

#################################
## COMBINE RAW DATA ##
#################################

es7716 = [[],[],[],[],[],[]]

es7716[0].append(0)

for i in _es7716:
    if len(i)>0:
        es7716[1].append(i[0])
    if len(i)>1:
        es7716[2].append(i[1])
    if len(i)>2:
        es7716[3].append(i[2])
    if len(i)>3:
        es7716[4].append(i[3])
    if len(i)>4:
        es7716[5].append(i[4])
        
#################################
## MEAN, MIN, MAX for plotting ##
#################################
means_7716 = []
errs_7716_min  = []
errs_7716_max  = []

for i in range(6):
    means_7716.append(np.mean(es7716[i]))
    if len(es7716[i])<=1:
        errs_7716_min.append(0)
        errs_7716_max.append(0)
    else:
        errs_7716_min.append(np.mean(es7716[i]) - np.min(es7716[i]))
        errs_7716_max.append(np.max(es7716[i]) - np.mean(es7716[i]))
        
means7716 = np.array(means_7716)
errs7716 = np.zeros((2,6))
errs7716[0,:] = errs_7716_min
errs7716[1,:] = errs_7716_max

# %%
total_slices = 17878347

# %%
slices_per_sec_mean_1929 = total_slices/means1929
slices_per_sec_mean_3858 = (total_slices * 2)/means3858
slices_per_sec_mean_7716 = (total_slices * 4)/means7716
# Out:
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_96049/3900409800.py:3: RuntimeWarning: divide by zero encountered in divide
#   slices_per_sec_mean_7716 = (total_slices * 4)/means7716

# %%
slices_per_sec_errs_1929 = np.array([
                            + total_slices/(means1929 - errs1929[0,:]) - total_slices/means1929,
                            - total_slices/(means1929 + errs1929[1,:]) + total_slices/means1929,
                            ])

slices_per_sec_errs_3858 = np.array([
                            + (total_slices * 2)/(means3858 - errs3858[0,:]) - (total_slices * 2)/means3858,
                            - (total_slices * 2)/(means3858 + errs3858[1,:]) + (total_slices * 2)/means3858,
                            ])

slices_per_sec_errs_7716 = np.array([
                            + (total_slices * 4)/(means_7716 - errs7716[0,:]) - (total_slices * 4)/means7716,
                            - (total_slices * 4)/(means_7716 + errs7716[1,:]) + (total_slices * 4)/means7716,
                            ])
# Out:
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_96049/2681382997.py:12: RuntimeWarning: divide by zero encountered in divide
#   + (total_slices * 4)/(means_7716 - errs7716[0,:]) - (total_slices * 4)/means7716,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_96049/2681382997.py:12: RuntimeWarning: invalid value encountered in subtract
#   + (total_slices * 4)/(means_7716 - errs7716[0,:]) - (total_slices * 4)/means7716,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_96049/2681382997.py:13: RuntimeWarning: divide by zero encountered in divide
#   - (total_slices * 4)/(means_7716 + errs7716[1,:]) + (total_slices * 4)/means7716,
# /var/folders/mb/zd6pgmt100q77s5fhn5xf4jw0000gq/T/ipykernel_96049/2681382997.py:13: RuntimeWarning: invalid value encountered in add
#   - (total_slices * 4)/(means_7716 + errs7716[1,:]) + (total_slices * 4)/means7716,

# %%
np.save('slices_per_sec_mean_1929.npy', slices_per_sec_mean_1929)
np.save('slices_per_sec_mean_3858.npy', slices_per_sec_mean_3858)
np.save('slices_per_sec_mean_7716.npy', slices_per_sec_mean_7716)

np.save('slices_per_sec_errs_1929.npy', slices_per_sec_errs_1929)
np.save('slices_per_sec_errs_3858.npy', slices_per_sec_errs_3858)
np.save('slices_per_sec_errs_7716.npy', slices_per_sec_errs_7716)

# %%
np.save('means_1929.npy', means_1929)
np.save('means_3858.npy', means_3858)
np.save('means_7716.npy', means_7716)

np.save('errs1929.npy', errs1929)
np.save('errs3858.npy', errs3858)
np.save('errs7716.npy', errs7716)
